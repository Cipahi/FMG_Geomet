# %%
# Import warnings and add a filter to ignore them
import warnings
warnings.simplefilter('ignore')

# %%
#Import libraries for plant optimization using machine learning and deep learning
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# classify the blending products based on the input features
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Cross validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Load data and prepare


#df = pd.read_csv(r"C:\Users\Suresh.Tripathi\Downloads\Geomet\data.csv")
df = pd.read_csv("C:/Users/Suresh.Tripathi/Downloads/Geomet/data.csv")
df.head(5)
# Out:
#    Seams   Inherant_Moist(%)  Ash(%)  Vol_Matter(%)  F.Carbon(%)  \
# 0      8                 5.3    55.7           17.9         21.1
# 1     18                 5.3    55.7           17.9         21.1
# 2     28                 5.3    55.7           17.9         21.1
# 3     38                 5.3    55.7           17.9         21.1
# 4     48                 5.3    55.7           17.9         21.1
#
#     CV_kcal/kg    SiO2 %   Yields (%)  coal_recoveries  specifc_gravity  \
# 0          2431      62.6          90               40              1.9
# 1          2431      62.6          90               40              1.9
# 2          2431      62.6          90               40              1.9
# 3          2431      62.6          90               40              1.9
# 4          2431      62.6          90               40              1.9
#
#    UCS_Mpa  Throughput_rates_tph       Products
# 0     19.0                   105  LowCV_Product
# 1      1.8                   105  LowCV_Product
# 2     17.0                   105  LowCV_Product
# 3     17.0                   105  LowCV_Product
# 4     17.0                   105  LowCV_Product

# %%
#check each column format and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Seams                 60 non-null     int64
#  1    Inherant_Moist(%)    60 non-null     float64
#  2   Ash(%)                60 non-null     float64
#  3   Vol_Matter(%)         60 non-null     float64
#  4   F.Carbon(%)           60 non-null     float64
#  5    CV_kcal/kg           60 non-null     int64
#  6    SiO2 %               60 non-null     float64
#  7   Yields (%)            60 non-null     int64
#  8   coal_recoveries       60 non-null     int64
#  9   specifc_gravity       60 non-null     float64
#  10  UCS_Mpa               60 non-null     float64
#  11  Throughput_rates_tph  60 non-null     int64
#  12  Products              60 non-null     int64
# dtypes: float64(7), int64(6)
# memory usage: 6.2 KB

# %%
 #Declare feature vector and target variable
X = df.drop('Products', axis=1)

y = df['Products']

# %%
X.head()
# Out:
#    Seams   Inherant_Moist(%)  Ash(%)  Vol_Matter(%)  F.Carbon(%)  \
# 0      8                 5.3    55.7           17.9         21.1
# 1     18                 5.3    55.7           17.9         21.1
# 2     28                 5.3    55.7           17.9         21.1
# 3     38                 5.3    55.7           17.9         21.1
# 4     48                 5.3    55.7           17.9         21.1
#
#     CV_kcal/kg    SiO2 %   Yields (%)  coal_recoveries  specifc_gravity  \
# 0          2431      62.6          90               40              1.9
# 1          2431      62.6          90               40              1.9
# 2          2431      62.6          90               40              1.9
# 3          2431      62.6          90               40              1.9
# 4          2431      62.6          90               40              1.9
#
#    UCS_Mpa  Throughput_rates_tph
# 0     19.0                   105
# 1      1.8                   105
# 2     17.0                   105
# 3     17.0                   105
# 4     17.0                   105

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Products, dtype: int64

# %%
# the products is non-balance and need correction
df['Products'].value_counts()
# Out:
# 0    30
# 1    18
# 2    12
# Name: Products, dtype: int64

# %%
# convert labels into multi-class values (0,1,2 etc)

y[y == 'HighCV_Product'] = 0
y[y == 'MediumCV_Product'] = 1
y[y =='LowCV_Product'] = 2

# %%
df['Products'] = pd.to_numeric(df['Products'])

# %%
# full correlation table
df.corr().style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T
{
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_31b5d_row7_col5 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_31b5d_row7_col8 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_31b5d_row7_col9 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_31b5d_row7_col10 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_31b5d_row7_col11 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_31b5d_row8_col0 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col1 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col2 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_31b5d_row8_col3 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col4 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col5 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col6 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col7, #T_31b5d_row9_col8, #T_31b5d_row10_col7 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col9 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_31b5d_row8_col11 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_31b5d_row8_col12 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_31b5d_row9_col0, #T_31b5d_row10_col4, #T_31b5d_row10_col5 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_31b5d_row9_col7 {
#   background-color: #d2e21b;
#   color: #000000;
# }
# #T_31b5d_row9_col10, #T_31b5d_row12_col10 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_31b5d_row9_col11, #T_31b5d_row11_col2, #T_31b5d_row11_col9 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_31b5d_row9_col12, #T_31b5d_row12_col9 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_31b5d_row10_col0 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_31b5d_row10_col1 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_31b5d_row10_col2, #T_31b5d_row10_col9, #T_31b5d_row10_col12 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_31b5d_row10_col3 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_31b5d_row10_col8 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_31b5d_row10_col11 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_31b5d_row11_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_31b5d_row11_col1 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_31b5d_row11_col8 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_31b5d_row11_col10 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_31b5d_row11_col12, #T_31b5d_row12_col11 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_31b5d_row12_col0 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_31b5d_row12_col5 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_31b5d_row12_col8 {
#   background-colo

# %%
 #Split data into separate training and test set
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train)
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_hat))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_hat))

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_hat))
# Out:
# LogisticRegression()
# LogisticRegression()
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00         7
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# Confusion matrix
# -------------------------------------------------------
# [[10  0  0]
#  [ 0  3  0]
#  [ 0  0  5]]

# %%
# Support Vector Machines
model = SVC()
model.fit(X_train, y_train)
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_hat))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_hat))

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_hat))
# Out:
# SVC()
# SVC()
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        20
#            1       1.00      0.73      0.85        15
#            2       1.00      1.00      1.00         7
#
#     accuracy                           0.90        42
#    macro avg       0.94      0.91      0.92        42
# weighted avg       0.92      0.90      0.90        42
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        10
#            1       1.00      0.33      0.50         3
#            2       1.00      1.00      1.00         5
#
#     accuracy                           0.89        18
#    macro avg       0.94      0.78      0.80        18
# weighted avg       0.91      0.89      0.87        18
#
# Confusion matrix
# -------------------------------------------------------
# [[10  0  0]
#  [ 2  1  0]
#  [ 0  0  5]]

# %%
# Random Forest
model = RandomForestClassifier(n_jobs=-1,random_state=123)
model.fit(X_train, y_train)
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_hat))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_hat))

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_hat))
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=123)
# RandomForestClassifier(n_jobs=-1, random_state=123)
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00         7
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# Confusion matrix
# -------------------------------------------------------
# [[10  0  0]
#  [ 0  3  0]
#  [ 0  0  5]]

# %%
# Neural nets
model = MLPClassifier()
model.fit(X_train, y_train)
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_hat))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_hat))

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_hat))
# Out:
# MLPClassifier()
# MLPClassifier()
# Train performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73        20
#            1       0.00      0.00      0.00        15
#            2       1.00      1.00      1.00         7
#
#     accuracy                           0.64        42
#    macro avg       0.52      0.67      0.58        42
# weighted avg       0.44      0.64      0.51        42
#
# Test performance
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       0.00      0.00      0.00         3
#            2       1.00      1.00      1.00         5
#
#     accuracy                           0.83        18
#    macro avg       0.59      0.67      0.62        18
# weighted avg       0.71      0.83      0.76        18
#
# Confusion matrix
# -------------------------------------------------------
# [[10  0  0]
#  [ 3  0  0]
#  [ 0  0  5]]

# %%
from xgboost import XGBClassifier

model = XGBClassifier(random_state=123)
model.fit(X_train, y_train)
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

print(model)
print('Train performance')
print('-------------------------------------------------------')
print(classification_report(y_train, y_train_hat))

print('Test performance')
print('-------------------------------------------------------')
print(classification_report(y_test, y_test_hat))

print('Roc_auc score')
print('-------------------------------------------------------')
print(roc_auc_score(y_test, y_test_hat))
print('')

print('Confusion matrix')
print('-------------------------------------------------------')
print(confusion_matrix(y_test, y_test_hat))
